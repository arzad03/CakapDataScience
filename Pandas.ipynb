# %% [markdown]
# <a href="https://colab.research.google.com/github/arzad03/CakapDataScience/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Import library pandas

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %% [markdown]
# Series merupakan suatu kolom bagian dari tabel dataframe yang merupakan 1 dimensional numpy array

# %%
var_a = [1, 7, 2]
hasil = pd.Series(var_a, name='gaji')

print(hasil)
# Out:
# 0    1
# 1    7
# 2    2
# Name: gaji, dtype: int64

# %%
print(hasil[1])
# Out:
# 7

# %%
#@title Label

hasil = pd.Series(var_a, index=["x", "y", "z"])
print(hasil)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(hasil["y"])
# Out:
# 7

# %%
#@title Dictionary

kalori = {"day1": 420, "day2": 380, "day3": 390}

hasil = pd.Series(kalori)
print(hasil)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# ## Dataframe

# %% [markdown]
# Dataframe beebentuk 2 dimensi data atau disebut multi-dimensional tables

# %%
#@title Create dataframe

data = {
  "date": ['2023-01-01', '2023-01-09', '2023-01-26'],
  "quantity": [2, 5, 9],
  "price": [50000, 250000, 450000]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)
# dataframe = 2 dimensi (row, column)

print(df)
# Out:
#          date  quantity   price
# 0  2023-01-01         2   50000
# 1  2023-01-09         5  250000
# 2  2023-01-26         9  450000

# %%
#@title Create dataframe from series

nama = pd.Series (['Ali', 'Budi', 'Citra'])
usia = pd.Series ([25, 30, 35])

df = pd. DataFrame ({'Nama':nama, 'Usia':usia})

print(df)
# Out:
#     Nama  Usia
# 0    Ali    25
# 1   Budi    30
# 2  Citra    35

# %% [markdown]
# ## Data Information

# %%
#@title Iterate dataframe

for i, j in df.iterrows():
    print(i, j)
# Out:
# 0 Nama    Ali
# Usia     25
# Name: 0, dtype: object
# 1 Nama    Budi
# Usia      30
# Name: 1, dtype: object
# 2 Nama    Citra
# Usia       35
# Name: 2, dtype: object

# %%
#@title Access specific item

for i in df:
    print (df[i][2])
# Out:
# Citra
# 35

# %%
# #@title Dataframe statistic

# # describe of the dataframe
# print('Describe: ')
# print(df.describe())
# print('--------------------------------------')

# # dimension of the dataframe
# print('Shape: ')
# print(df.shape)
# print('--------------------------------------')

# # showing info about the data
# print('Info: ')
# print(df.info())
# print('--------------------------------------')

# # correlation between columns
# print('Correlation: ')
# print(df.corr())

import pandas as pd

# Contoh data
data = {
    'Nama': ['Ali', 'Budi', 'Citra'],
    'Usia': [25, 30, 35]
}

# Membuat DataFrame
df = pd.DataFrame(data)

# Menampilkan ringkasan statistik dari kolom 'Usia'
print("Describe:")
print(df['Usia'].describe())
print("--------------------------------------")

# Menampilkan bentuk DataFrame (jumlah baris dan kolom)
print("Shape:")
print(df.shape)
print("--------------------------------------")

# Menampilkan informasi tentang DataFrame (tipe data, jumlah data, dsb.)
print("Info:")
print(df.info())
print("--------------------------------------")

# Menghitung korelasi antara kolom numerik
print("Correlation:")
print(df.corr(numeric_only=True))
# Out:
# Describe:
# count     3.0
# mean     30.0
# std       5.0
# min      25.0
# 25%      27.5
# 50%      30.0
# 75%      32.5
# max      35.0
# Name: Usia, dtype: float64
# --------------------------------------
# Shape:
# (3, 2)
# --------------------------------------
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nama    3 non-null      object
#  1   Usia    3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes
# None
# --------------------------------------
# Correlation:
#       Usia
# Usia   1.0

# %% [markdown]
# ## Load File as Dataframe

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@title Upload file

sales_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/customer_shopping_data.csv')
sales_data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# 2               Cash    9/11/2021         Metrocity
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %%
# sales_data.head()
# sales_data.tail()
# sales_data.head(25)
sales_data.tail(15)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 99442    I105959     C131810  Female   45         Clothing         4  1200.32
# 99443    I152790     C223470    Male   41        Cosmetics         4   162.64
# 99444    I131678     C119287    Male   24             Toys         1    35.84
# 99445    I750456     C270290  Female   35  Food & Beverage         5    26.15
# 99446    I327966     C107209  Female   32  Food & Beverage         1     5.23
# 99447    I281214     C288090  Female   37             Toys         3   107.52
# 99448    I332105     C231387  Female   65            Shoes         4  2400.68
# 99449    I134399     C953724    Male   65         Clothing         1   300.08
# 99450    I170504     C226974  Female   28            Books         1    15.15
# 99451    I675411     C513603    Male   50             Toys         5   179.20
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 99442     Debit Card     1/2/2021      Istinye Park
# 99443     Debit Card   26/07/2021  Mall of Istanbul
# 99444           Cash   26/11/2021  Mall of Istanbul
# 99445           Cash     7/5/2021            Kanyon
# 99446           Cash     5/2/2023      Metropol AVM
# 99447           Cash   21/02/2021      Metropol AVM
# 99448    Credit Card   29/08/2021      Metropol AVM
# 99449           Cash     1/1/2023            Kanyon
# 99450           Cash   28/02/2023      Zorlu Center
# 99451           Cash    9/10/2021      Metropol AVM
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul

# %%
#@title Connect G-Drive

sales_data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/customer_shopping_data.csv')

sales_data.head()
# sales_data.head(10)
# sales_data.tail(8)
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
#@title File txt

data_txt = pd.read_csv('/content/drive/My Drive/Colab Notebooks/fruit_data_with_colors.txt', delimiter='\t')
data_txt.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %% [markdown]
# ## Analytics Dataframe

# %%
sales_data.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %%
print('Shape: ')
print(sales_data.shape)
print('--------------------------------------')

print('\nInfo: ')
print(sales_data.info())
print('--------------------------------------')

print('\nCorrelation: ')
print(sales_data.corr())
# Out:
# Shape:
# (99457, 10)
# --------------------------------------
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB
# None
# --------------------------------------
#
# Correlation:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-01ff040ebb19> in <cell line: 10>()
#       8
#       9 print('\nCorrelation: ')
# ---> 10 print(sales_data.corr())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in as_array(self, dtype, copy, na_value)
#    1692                 arr.flags.writeable = False
#    1693         else:
# -> 1694             arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695             # The underlying data was copied within _interleave, so no need
#    1696             # to further copy if copy=True or setting na_value
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in _interleave(self, dtype, na_value)
#    1751             else:
#    1752                 arr = blk.get_values(dtype)
# -> 1753             result[rl.indexer] = arr
#    1754             itemmask[rl.indexer] = 1
#    1755
#
# ValueError: could not convert string to float: 'I138884'

# %% [markdown]
# ## Filter Dataframe

# %%
#@title Filter with logic operator

data_with_quantity_more_than_3_product = sales_data[sales_data.quantity >= 3]
data_with_quantity_more_than_3_product
# Out:
#       invoice_no customer_id  gender  age    category  quantity    price  \
# 0        I138884     C241288  Female   28    Clothing         5  1500.40
# 1        I317333     C111565    Male   21       Shoes         3  1800.51
# 3        I173702     C988172  Female   66       Shoes         5  3000.85
# 4        I337046     C189076  Female   53       Books         4    60.60
# 5        I227836     C657758  Female   28    Clothing         5  1500.40
# ...          ...         ...     ...  ...         ...       ...      ...
# 99448    I332105     C231387  Female   65       Shoes         4  2400.68
# 99451    I675411     C513603    Male   50        Toys         5   179.20
# 99452    I219422     C441542  Female   45    Souvenir         5    58.65
# 99455    I702964     C800631    Male   56  Technology         4  4200.00
# 99456    I232867     C273973  Female   36    Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# 5        Credit Card   24/05/2022    Forum Istanbul
# ...              ...          ...               ...
# 99448    Credit Card   29/08/2021      Metropol AVM
# 99451           Cash    9/10/2021      Metropol AVM
# 99452    Credit Card   21/09/2022            Kanyon
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [59862 rows x 10 columns]

# %%
#@title Multiple Filter

multiple_filter = sales_data[(sales_data.quantity >= 3) & (sales_data.shopping_mall == 'Kanyon') & (sales_data.age > 30) & (sales_data.payment_method == 'Cash')]
multiple_filter
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 4        I337046     C189076  Female   53            Books         4    60.60
# 23       I252275     C313348    Male   44       Technology         5  5250.00
# 58       I263803     C112279  Female   67  Food & Beverage         3    15.69
# 59       I335713     C158837  Female   36            Books         4    60.60
# 71       I251356     C493252  Female   47        Cosmetics         4   162.64
# ...          ...         ...     ...  ...              ...       ...      ...
# 99264    I229013     C136011    Male   65         Souvenir         4    46.92
# 99340    I800346     C597938    Male   68  Food & Beverage         4    20.92
# 99359    I285851     C170105  Female   39         Clothing         4  1200.32
# 99439    I522661     C776199  Female   58  Food & Beverage         4    20.92
# 99445    I750456     C270290  Female   35  Food & Beverage         5    26.15
#
#       payment_method invoice_date shopping_mall
# 4               Cash   24/10/2021        Kanyon
# 23              Cash   26/10/2021        Kanyon
# 58              Cash   23/06/2021        Kanyon
# 59              Cash   14/12/2021        Kanyon
# 71              Cash     4/9/2021        Kanyon
# ...              ...          ...           ...
# 99264           Cash   26/05/2021        Kanyon
# 99340           Cash    12/2/2023        Kanyon
# 99359           Cash   31/07/2021        Kanyon
# 99439           Cash     1/2/2021        Kanyon
# 99445           Cash     7/5/2021        Kanyon
#
# [3994 rows x 10 columns]

# %%
#@title Filter with isin

shopping_mall= ['Kanyon', 'Mall of Istanbul', 'Metropol AVM']

spesific_payment_method = sales_data[sales_data.shopping_mall.isin(shopping_mall)]
# spesific_payment_method = sales_data[sales_data.category.isin(['Shoes', 'Books'])]
spesific_payment_method
# Out:
#       invoice_no customer_id  gender  age  category  quantity    price  \
# 0        I138884     C241288  Female   28  Clothing         5  1500.40
# 3        I173702     C988172  Female   66     Shoes         5  3000.85
# 4        I337046     C189076  Female   53     Books         4    60.60
# 7        I293112     C176086  Female   32  Clothing         2   600.16
# 9        I326945     C283361  Female   60  Clothing         2   600.16
# ...          ...         ...     ...  ...       ...       ...      ...
# 99448    I332105     C231387  Female   65     Shoes         4  2400.68
# 99449    I134399     C953724    Male   65  Clothing         1   300.08
# 99451    I675411     C513603    Male   50      Toys         5   179.20
# 99452    I219422     C441542  Female   45  Souvenir         5    58.65
# 99456    I232867     C273973  Female   36  Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# 7        Credit Card   13/01/2021  Mall of Istanbul
# 9        Credit Card   22/08/2021            Kanyon
# ...              ...          ...               ...
# 99448    Credit Card   29/08/2021      Metropol AVM
# 99449           Cash     1/1/2023            Kanyon
# 99451           Cash    9/10/2021      Metropol AVM
# 99452    Credit Card   21/09/2022            Kanyon
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [49927 rows x 10 columns]

# %%
#@title Filter with str accessor

# sales_data[sales_data.shopping_mall.str.startswith('Ma')]
sales_data[sales_data.shopping_mall.str.endswith('ul')]
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 5        I227836     C657758  Female   28         Clothing         5  1500.40
# 7        I293112     C176086  Female   32         Clothing         2   600.16
# 26       I196704     C289625  Female   25        Cosmetics         5   203.30
# 30       I161949     C159164  Female   66             Toys         3   107.52
# ...          ...         ...     ...  ...              ...       ...      ...
# 99432    I133264     C289915  Female   41            Books         2    30.30
# 99443    I152790     C223470    Male   41        Cosmetics         4   162.64
# 99444    I131678     C119287    Male   24             Toys         1    35.84
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 1         Debit Card   12/12/2021    Forum Istanbul
# 5        Credit Card   24/05/2022    Forum Istanbul
# 7        Credit Card   13/01/2021  Mall of Istanbul
# 26       Credit Card   20/04/2022  Mall of Istanbul
# 30        Debit Card     4/7/2022  Mall of Istanbul
# ...              ...          ...               ...
# 99432     Debit Card   23/02/2022  Mall of Istanbul
# 99443     Debit Card   26/07/2021  Mall of Istanbul
# 99444           Cash   26/11/2021  Mall of Istanbul
# 99453           Cash   22/09/2021    Forum Istanbul
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [24890 rows x 10 columns]

# %%
#@title Filter with nlargest & nsmallest

#Mengambil 3 data belanja pengguna dengan  total pembelian terbanyak
sales_data.nlargest(5, 'price')
# Out:
#     invoice_no customer_id  gender  age    category  quantity   price  \
# 23     I252275     C313348    Male   44  Technology         5  5250.0
# 69     I883721     C236859  Female   44  Technology         5  5250.0
# 363    I194017     C462011  Female   67  Technology         5  5250.0
# 391    I252528     C333065    Male   47  Technology         5  5250.0
# 570    I311849     C178487    Male   27  Technology         5  5250.0
#
#     payment_method invoice_date     shopping_mall
# 23            Cash   26/10/2021            Kanyon
# 69     Credit Card   19/11/2021  Mall of Istanbul
# 363           Cash     3/1/2022            Kanyon
# 391     Debit Card    4/10/2022       Cevahir AVM
# 570     Debit Card   21/04/2021       Cevahir AVM

# %%
sales_data.nsmallest(3, 'price')
# Out:
#    invoice_no customer_id  gender  age         category  quantity  price  \
# 21    I412481     C125696  Female   27  Food & Beverage         1   5.23
# 35    I339732     C276887    Male   68  Food & Beverage         1   5.23
# 84    I249424     C158160    Male   22  Food & Beverage         1   5.23
#
#    payment_method invoice_date      shopping_mall
# 21           Cash     1/5/2021        Cevahir AVM
# 35    Credit Card     4/1/2023  Emaar Square Mall
# 84           Cash   18/02/2022   Mall of Istanbul

# %%
#@title Filter with Query

sales_data.query('gender == "Male" and age > 25 and payment_method == "Cash" and quantity >=3')
# Out:
#       invoice_no customer_id gender  age         category  quantity    price  \
# 23       I252275     C313348   Male   44       Technology         5  5250.00
# 27       I217053     C192344   Male   50            Shoes         4  2400.68
# 63       I157285     C123427   Male   66         Clothing         4  1200.32
# 70       I402376     C309926   Male   34            Shoes         5  3000.85
# 72       I292239     C109871   Male   38  Food & Beverage         5    26.15
# ...          ...         ...    ...  ...              ...       ...      ...
# 99421    I419578     C279804   Male   58            Books         3    45.45
# 99430    I336082     C316368   Male   26         Clothing         5  1500.40
# 99441    I203187     C235554   Male   38  Food & Beverage         4    20.92
# 99451    I675411     C513603   Male   50             Toys         5   179.20
# 99455    I702964     C800631   Male   56       Technology         4  4200.00
#
#       payment_method invoice_date      shopping_mall
# 23              Cash   26/10/2021             Kanyon
# 27              Cash   10/10/2022  Emaar Square Mall
# 63              Cash     6/3/2022   Mall of Istanbul
# 70              Cash    10/9/2022     Forum Istanbul
# 72              Cash   21/08/2022   Mall of Istanbul
# ...              ...          ...                ...
# 99421           Cash   19/11/2022  Emaar Square Mall
# 99430           Cash   26/04/2021   Mall of Istanbul
# 99441           Cash     2/3/2023       Zorlu Center
# 99451           Cash    9/10/2021       Metropol AVM
# 99455           Cash   16/03/2021       Istinye Park
#
# [9113 rows x 10 columns]

# %% [markdown]
# ## Group Dataframe

# %%
sales_data.groupby('gender').agg({'price': 'sum'})
# Out:
#               price
# gender
# Female  40931801.62
# Male    27619564.29

# %%
sales_data.groupby('payment_method').agg({'customer_id': 'count'})
# Out:
#                 customer_id
# payment_method
# Cash                  44447
# Credit Card           34931
# Debit Card            20079

# %%
sales_data.groupby(['category', 'gender']).count()[['customer_id']]
# Out:
#                         customer_id
# category        gender
# Books           Female         2906
#                 Male           2075
# Clothing        Female        20652
#                 Male          13835
# Cosmetics       Female         9070
#                 Male           6027
# Food & Beverage Female         8804
#                 Male           5972
# Shoes           Female         5967
#                 Male           4067
# Souvenir        Female         3017
#                 Male           1982
# Technology      Female         2981
#                 Male           2015
# Toys            Female         6085
#                 Male           4002

# %% [markdown]
# ## Replace Dataframe

# %%
# Create Dataframe

data = {'Product': ['Product A', 'Product B', 'Product C', 'Product D'],
        'Region': ['Jakarta', 'Bandung', 'Bogor', 'Tangerang'],
        'Sales': [100000, 50000, 70000, 90000]}

df = pd.DataFrame(data)
print(df)
# Out:
#      Product     Region   Sales
# 0  Product A    Jakarta  100000
# 1  Product B    Bandung   50000
# 2  Product C      Bogor   70000
# 3  Product D  Tangerang   90000

# %%
#@title Replace Values in Column
# replace(oldvalue, newvalue)

df['Region'] = df['Region'].replace('Jakarta','DKI Jakarta')
print(df)
# Out:
#      Product       Region   Sales
# 0  Product A  DKI Jakarta  100000
# 1  Product B      Bandung   50000
# 2  Product C        Bogor   70000
# 3  Product D    Tangerang   90000

# %%
df['Product'] = df['Product'].replace('Product D', 'Product New')
print(df)
# Out:
#        Product       Region   Sales
# 0    Product A  DKI Jakarta  100000
# 1    Product B      Bandung   50000
# 2    Product C        Bogor   70000
# 3  Product New    Tangerang   90000

# %%
df['Sales'] = df['Sales'].replace([100000, 20000])
print(df)
# Out:
#        Product       Region   Sales
# 0    Product A  DKI Jakarta  100000
# 1    Product B      Bandung   50000
# 2    Product C        Bogor   70000
# 3  Product New    Tangerang   90000
# <ipython-input-37-2c0053b0c75f>:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['Sales'] = df['Sales'].replace([100000, 20000])

# %%
#@title Replace Multiple Values in Column

df['Product'] = df['Product'].replace(['Product A', 'Product B'], 'Banana')
print(df)
# Out:
#        Product       Region   Sales
# 0       Banana  DKI Jakarta  100000
# 1       Banana      Bandung   50000
# 2    Product C        Bogor   70000
# 3  Product New    Tangerang   90000

# %%
df['Region'] = df['Region'].replace(['Bandung', 'Bogor'], ['Cikarang', 'Bekasi'])
print(df)
# Out:
#        Product       Region   Sales
# 0       Banana  DKI Jakarta  100000
# 1       Banana     Cikarang   50000
# 2    Product C       Bekasi   70000
# 3  Product New    Tangerang   90000

# %% [markdown]
# ## Dataframe Duplicated Data

# %%
# Create a dataframe
data = [{'species': 'Esox lucius', 'length': 120, 'weight': 8.1, 'age': 3},
        {'species': 'Esox lucius', 'length': 120, 'weight': 8.1, 'age': 3},
        {'species': 'Esox lucius', 'length': 120, 'weight': 8.1, 'age': 3},
        {'species': 'Esox lucius', 'length': 120, 'weight': 7.7, 'age': 2},
        {'species': 'Esox lucius', 'length': 110, 'weight': 7.9, 'age': 2},
        {'species': 'Cyprinus carpio', 'length': 56, 'weight': 8.3, 'age': 13},
        {'species': 'Cyprinus carpio', 'length': 36, 'weight': 7.9, 'age': 23},
        {'species': 'Cyprinus carpio', 'length': 46, 'weight': 8.1, 'age': 13},
        {'species': 'Cyprinus carpio', 'length': 46, 'weight': 8.1, 'age': 13},
        {'species': 'Salmo trutta', 'length': 40, 'weight': 7.5, 'age': 5},
        {'species': 'Salmo trutta', 'length': 38, 'weight': 7.4, 'age': 4},
        {'species': 'Oncorhynchus mykiss', 'length': 42, 'weight': 7.6, 'age': 5},
        {'species': 'Oncorhynchus mykiss', 'length': 42, 'weight': 7.6, 'age': 5},
        {'species': 'Salmo salar', 'length': 44, 'weight': 7.7, 'age': 5}]

df = pd.DataFrame(data)
df
# Out:
#                 species  length  weight  age
# 0           Esox lucius     120     8.1    3
# 1           Esox lucius     120     8.1    3
# 2           Esox lucius     120     8.1    3
# 3           Esox lucius     120     7.7    2
# 4           Esox lucius     110     7.9    2
# 5       Cyprinus carpio      56     8.3   13
# 6       Cyprinus carpio      36     7.9   23
# 7       Cyprinus carpio      46     8.1   13
# 8       Cyprinus carpio      46     8.1   13
# 9          Salmo trutta      40     7.5    5
# 10         Salmo trutta      38     7.4    4
# 11  Oncorhynchus mykiss      42     7.6    5
# 12  Oncorhynchus mykiss      42     7.6    5
# 13          Salmo salar      44     7.7    5

# %%
#@title Identification Duplicate

df.duplicated()
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# dtype: bool

# %%
df2 = df.copy()
df2
# Out:
#                 species  length  weight  age
# 0           Esox lucius     120     8.1    3
# 1           Esox lucius     120     8.1    3
# 2           Esox lucius     120     8.1    3
# 3           Esox lucius     120     7.7    2
# 4           Esox lucius     110     7.9    2
# 5       Cyprinus carpio      56     8.3   13
# 6       Cyprinus carpio      36     7.9   23
# 7       Cyprinus carpio      46     8.1   13
# 8       Cyprinus carpio      46     8.1   13
# 9          Salmo trutta      40     7.5    5
# 10         Salmo trutta      38     7.4    4
# 11  Oncorhynchus mykiss      42     7.6    5
# 12  Oncorhynchus mykiss      42     7.6    5
# 13          Salmo salar      44     7.7    5

# %%
#@title Add new column duplicated

df2['duplicated'] = df2.duplicated()
df2
# Out:
#                 species  length  weight  age  duplicated
# 0           Esox lucius     120     8.1    3       False
# 1           Esox lucius     120     8.1    3        True
# 2           Esox lucius     120     8.1    3        True
# 3           Esox lucius     120     7.7    2       False
# 4           Esox lucius     110     7.9    2       False
# 5       Cyprinus carpio      56     8.3   13       False
# 6       Cyprinus carpio      36     7.9   23       False
# 7       Cyprinus carpio      46     8.1   13       False
# 8       Cyprinus carpio      46     8.1   13        True
# 9          Salmo trutta      40     7.5    5       False
# 10         Salmo trutta      38     7.4    4       False
# 11  Oncorhynchus mykiss      42     7.6    5       False
# 12  Oncorhynchus mykiss      42     7.6    5        True
# 13          Salmo salar      44     7.7    5       False

# %%
#@title Drop Duplicate

df_new = df.drop_duplicates()
df_new
# Out:
#                 species  length  weight  age
# 0           Esox lucius     120     8.1    3
# 3           Esox lucius     120     7.7    2
# 4           Esox lucius     110     7.9    2
# 5       Cyprinus carpio      56     8.3   13
# 6       Cyprinus carpio      36     7.9   23
# 7       Cyprinus carpio      46     8.1   13
# 9          Salmo trutta      40     7.5    5
# 10         Salmo trutta      38     7.4    4
# 11  Oncorhynchus mykiss      42     7.6    5
# 13          Salmo salar      44     7.7    5

# %%
df
# Out:
#                 species  length  weight  age
# 0           Esox lucius     120     8.1    3
# 1           Esox lucius     120     8.1    3
# 2           Esox lucius     120     8.1    3
# 3           Esox lucius     120     7.7    2
# 4           Esox lucius     110     7.9    2
# 5       Cyprinus carpio      56     8.3   13
# 6       Cyprinus carpio      36     7.9   23
# 7       Cyprinus carpio      46     8.1   13
# 8       Cyprinus carpio      46     8.1   13
# 9          Salmo trutta      40     7.5    5
# 10         Salmo trutta      38     7.4    4
# 11  Oncorhynchus mykiss      42     7.6    5
# 12  Oncorhynchus mykiss      42     7.6    5
# 13          Salmo salar      44     7.7    5

# %% [markdown]
# ## Soal
#
# Download dataset berikut :
#
# https://drive.google.com/file/d/1Yb0B3q2QjdQpuUlxhKOmyn5JcnQ_-w3x/view?usp=drive_link
#
# * Buat project baru di colab
# * Load dataset
# * Lihat analytical dataframe
# * Check duplicate & handle duplicate
# * Lakukan filter dataframe
# * Lakukan group dataframe
# * Lakukan replace dataframe
